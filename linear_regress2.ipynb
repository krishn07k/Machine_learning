# %% [markdown]
# <a href="https://colab.research.google.com/github/krishn07k/Machine_learning/blob/main/linear_regress2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data = pd.read_csv('/content/test.csv')

# %%
data
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
data.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area  status
# 0     24.98298     121.54024                        37.9       0
# 1     24.98034     121.53951                        42.2       1
# 2     24.98746     121.54391                        47.3       1
# ...

# %%
features = ['X2 house age']
x_data = data[features]
y_data = data['Y house price of unit area']

# %%
x_data
# Out:
#      X2 house age
# 0            32.0
# 1            19.5
# 2            13.3
# 3            13.3
# 4             5.0
# ..            ...
# 409          13.7
# 410           5.6
# 411          18.8
# 412           8.1
# 413           6.5
#
# [414 rows x 1 columns]

# %%
plt.scatter(x_data,y_data)
plt.xlabel('house age', fontsize=10)
plt.ylabel('price ',fontsize=10)
# Out:
# Text(0, 0.5, 'price ')

# %%
regress=linear_model.LinearRegression()

# %%
regress.fit(data[['X2 house age']],y_data)
# Out:
# LinearRegression()

# %%
regress.predict([[15]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([38.66237076])
